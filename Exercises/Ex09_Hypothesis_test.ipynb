# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N_bins = 100
mu_bg = .1
N_tot = N_bins*mu_bg
def f_lambda(x, N_tot, N_bins):
    return 2*x*np.log(N_bins/N_tot*x) + 2*(N_tot-x)*np.log(N_bins*(N_tot-x)/((N_bins-1)*N_tot) )
x_arr = np.linspace(1, 250, 1000)
lambda_arr = f_lambda(x_arr, N_tot, N_bins)

# %% [markdown]
# ## uniform distribution on a sphere

# %%
def sample_spherical(npoints, ndim=3):
    vec = np.random.randn(ndim, npoints)
    vec /= np.linalg.norm(vec, axis=0)
    return vec
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d

phi = np.linspace(0, np.pi, 20)
theta = np.linspace(0, 2 * np.pi, 40)
x = np.outer(np.sin(theta), np.cos(phi))
y = np.outer(np.sin(theta), np.sin(phi))
z = np.outer(np.cos(theta), np.ones_like(phi))

xi, yi, zi = sample_spherical(100)

fig, ax = plt.subplots(1, 1, subplot_kw={'projection':'mollweide', 'aspect':'auto'}, figsize = (10,12))
#ax.plot_wireframe(x, y, z, color='k', rstride=1, cstride=1)
#ax.scatter(xi, yi, zi, s=100, c='r', zorder=10)
plt.grid(True)
